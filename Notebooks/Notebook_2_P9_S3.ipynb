# %% [markdown]
# # AWS

# %%
# !python3 --version
# Out:
# Python 3.12.12

# %% [markdown]
# ## 1- Installation de AWS Cli

# %%
# !pip install awscli
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 98.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9.1
#     Uninstalling rsa-4.9.1:
#       Successfully uninstalled rsa-4.9.1
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
# ...

# %%
# !aws --version
# Out:
# aws-cli/1.44.16 Python/3.12.12 Linux/6.6.105+ botocore/1.42.26

# %% [markdown]
# Paramètres de configuration du compte AWS

# %%
# !aws configure
# Out:
# AWS Access Key ID [None]: AKIA2SNB4HMQTAUSXHOE
# AWS Secret Access Key [None]: 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
# Default region name [None]: eu-west-3
# Default output format [None]: json

# %% [markdown]
# Loading des data dans le bucket S3 AWS

# %%
# !aws s3 mb s3://aws-bucket-p9
# Out:
# make_bucket failed: s3://aws-bucket-p9 An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
# !aws s3 ls
# Out:
# 2026-01-13 14:06:34 aws-bucket-p9

# %%
# !aws s3 sync /content/drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test s3://aws-bucket-p9/fruits/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# upload: drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test/Plum 3/178_100.jpg to s3://aws-bucket-p9/fruits/Plum 3/178_100.jpg
# upload: drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test/Plum 3/172_100.jpg to s3://aws-bucket-p9/fruits/Plum 3/172_100.jpg
# upload: drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test/Plum 3/177_100.jpg to s3://aws-bucket-p9/fruits/Plum 3/177_100.jpg
# upload: drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test/Plum 3/176_100.jpg to s3://aws-bucket-p9/fruits/Plum 3/176_100.jpg
# upload: drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test/Plum 3/173_100.jpg to s3://aws-bucket-p9/fruits/Plum 3/173_100.jpg
# upload: drive/MyDrive/fruits/fruits-360_dataset/fruits-360/Test/Plum 3/175_100.jpg to s3://aws-bucket-p9/fruits/Plum 3/175_100.jpg
# ...
