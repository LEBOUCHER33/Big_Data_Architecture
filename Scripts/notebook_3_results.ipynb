# %%
import pandas as pd

# %%
df_local = pd.read_parquet('../data_pca.parquet')

# %%
df_local.head()
# Out:
#                                                 path    modificationTime  \
# 0  s3://aws-bucket-p9/fruits/fruits-360-original-... 2026-01-13 14:28:08
# 1  s3://aws-bucket-p9/fruits/fruits-360-original-... 2026-01-13 14:24:01
#
#    length                                            content        label  \
# 0  125373  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  apple_hit_1
# 1  125135  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...  apple_hit_1
#
#                                       features_array  \
# 0  [0.2426833, 0.47348952, 1.4225341, 0.0, 0.8024...
# 1  [0.16454755, 0.34861296, 1.1157503, 0.0, 1.091...
#
#                                             features  \
# 0  {'type': 1, 'size': None, 'indices': None, 'va...
# 1  {'type': 1, 'size': None, 'indices': None, 'va...
#
#                                      features_scaled  \
# 0  {'type': 1, 'size': None, 'indices': None, 'va...
# 1  {'type': 1, 'size': None, 'indices': None, 'va...
#
# ...

# %%
df_local.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   path              2 non-null      str
#  1   modificationTime  2 non-null      datetime64[ns]
#  2   length            2 non-null      int64
#  3   content           2 non-null      object
#  4   label             2 non-null      str
#  5   features_array    2 non-null      object
#  6   features          2 non-null      object
#  7   features_scaled   2 non-null      object
#  8   features_pca      2 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(5), str(2)
# memory usage: 508.0+ bytes
